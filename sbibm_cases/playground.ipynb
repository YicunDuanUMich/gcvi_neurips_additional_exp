# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import matplotlib.pyplot as plt
import sbibm

from sbibm_cases.run import train_and_test

# %%
device = torch.device("cuda:1")

# %%
sbibm.get_available_tasks()

# %%
out_dict = train_and_test(task_name="gaussian_mixture",
                          seed=1234,
                          device=device,
                          use_elbo=True)

# %%
plt.plot(out_dict["training_loss"], linewidth=0.1)
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.show()

# %%
out_dict["test_dict_list"][0]["est_mu"]

# %%
out_dict["test_dict_list"][0]["est_sigma2"]

# %%
out_dict["test_dict_list"][0]["true_mu"]

# %%
out_dict["test_dict_list"][0]["true_sigma2"]
